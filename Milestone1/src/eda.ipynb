# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

# %% [markdown]
# # cases_train.csv

# %%
df = pd.read_csv("../data/cases_train.csv")

# %%
# see what the dataframe looks like
df.head(2)
# Out:
#    age  sex       province country  latitude  longitude date_confirmation  \
# 0  NaN  NaN          Delhi   India  28.61474   77.20910        26.05.2020
# 1  NaN  NaN  Uttar Pradesh   India  25.43609   81.84718        20.05.2020
#
#   additional_information                                             source  \
# 0                    NaN  https://twitter.com/CMODelhi/status/1265203060...
# 1                    NaN                       https://t.me/indiacovid/5222
#
#         outcome
# 0     recovered
# 1  hospitalized

# %% [markdown]
# ## Statistical information

# %%
cases_columns = ['age', 'sex', 'province', 'country', 'source', 'outcome']
for attribute in cases_columns:    
    print(f"statistics for {attribute} column")
    print(df[attribute].describe())
    print("-------------------------")
# Out:
# statistics for age column
# count     158371
# unique       337
# top        35-59
# freq       10785
# Name: age, dtype: object
# -------------------------
# statistics for sex column
# count     160552
# unique         2
# top         male
# freq       88635
# Name: sex, dtype: object
# -------------------------
# statistics for province column
# count          363530
# unique           1106
# top       Maharashtra
# freq            74894
# Name: province, dtype: object
# -------------------------
# statistics for country column
# count     367618
# unique       131
# top        India
# freq      212411
# Name: country, dtype: object
# -------------------------
# statistics for source column
# count           239158
# unique            7250
# top       PH Data Drop
# freq             10834
# Name: source, dtype: object
# -------------------------
# statistics for outcome column
# count              367636
# unique                  4
# top       nonhospitalized
# freq               150000
# Name: outcome, dtype: object
# -------------------------

# %% [markdown]
# ## Visualizations

# %%
attribute_hist_fig_sizes = [(50,6),(1,4),(40,4),(30,4),(50,6),(1,4)]
for i, attribute in enumerate(cases_columns):
    # source column was exlucded from the histograms. Since it has over 7K unique values, jupyter notebook
    # could not properly render it.
    if attribute == "source":
        continue
    plt.figure()
    plt.title(attribute)
    df[attribute].hist(figsize=attribute_hist_fig_sizes[i], xrot=90)

# %%
# age
# plot for age is saved later in section 1.3

# sex
plt.figure(figsize=(1,4))
plt.title("Distribution of genders for cases_train.csv")
plt.xlabel("Genders")
plt.ylabel("Count")
df['sex'].hist(xrot=90)
plt.savefig("../plots/cases_train_sex_distribution.png", facecolor='white', bbox_inches = "tight")

# province
fig = plt.figure(figsize=(40,4))
plt.title("Distribution of province_states with >200 cases in cases_train.csv")
plt.xlabel("Province")
plt.ylabel("Count")
plt.xticks(rotation=90)
df_prov = df.groupby(['province'], as_index=False).count()
df_prov = df_prov[df_prov['country'] > 200]
df_prov = df_prov.sort_values(by='country', ascending=False)
plt.bar(df_prov['province'], df_prov['country'])
plt.savefig("../plots/cases_train_provinces>200cases.png", facecolor='white', bbox_inches = "tight")

# country
plt.figure(figsize=(30,4))
plt.title("Distribution of countries for cases_train.csv")
plt.xlabel("Country")
plt.ylabel("Count")
plt.xticks(rotation=90)
df_country = df.groupby(['country'], as_index=False).count()
df_country = df_country.sort_values(by='latitude', ascending=False) # per review of data, only two rows are missing latitude, so it's an appropriate column to count by
plt.bar(df_country['country'], df_country['latitude'])
plt.savefig("../plots/cases_train_countries_distribution.png", facecolor='white', bbox_inches = "tight")

# outcome
plt.figure(figsize=(1,4))
plt.title("Distribution of outcomes for cases_train.csv")
plt.xlabel("Outcomes")
plt.ylabel("Count")
df['outcome'].hist(xrot=90)
plt.savefig("../plots/cases_train_outcome_distribution.png", facecolor='white', bbox_inches = "tight")

# %% [markdown]
# #### Visualization for date_confirmation

# %%
def convert_to_datetime(row):
    date_string = row['date_confirmation']
    if '-' in str(date_string):
        return
    return pd.to_datetime(date_string)

# %%
# remove date ranges so data can be plotted
df['converted_datetime'] = df.apply(convert_to_datetime, axis=1)

# %%
plt.figure()
plt.title('Count of Date Confirmed')
plt.ylabel('Count')
plt.xlabel('Date')
df['converted_datetime'].hist()
plt.savefig("../plots/cases_train_date_confirmed.png", facecolor='white', bbox_inches = "tight")

# %% [markdown]
# #### Visualization for longitude and latitude

# %%
# modified from https://stackoverflow.com/questions/53233228/plot-latitude-longitude-from-csv-in-python-3-6
geometry = [Point(xy) for xy in zip(df['longitude'], df['latitude'])]
gdf = GeoDataFrame(df, geometry=geometry) 

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=1);
plt.title('Heatmap of Cases')
plt.savefig("../plots/cases_train_lat_long_mapped.png", facecolor='white', bbox_inches = "tight")

# %% [markdown]
# ## Number of missing values

# %%
df.isnull().sum()
# Out:
# age                       209265
# sex                       207084
# province                    4106
# country                       18
# latitude                       2
# longitude                      2
# date_confirmation            288
# additional_information    344912
# source                    128478
# outcome                        0
# dtype: int64

# %% [markdown]
# # location.csv

# %%
df_loc = pd.read_csv("../data/location.csv")

# %%
# see what the dataframe looks like
df_loc.head(2)
# Out:
#   Province_State Country_Region          Last_Update       Lat      Long_  \
# 0            NaN    Afghanistan  2020-09-20 04:22:56  33.93911  67.709953
# 1            NaN        Albania  2020-09-20 04:22:56  41.15330  20.168300
#
#    Confirmed  Deaths  Recovered  Active Combined_Key  Incidence_Rate  \
# 0      38919    1437      32576  4906.0  Afghanistan       99.976005
# 1      12226     358       6888  4980.0      Albania      424.838418
#
#    Case-Fatality_Ratio
# 0             3.692284
# 1             2.928186

# %% [markdown]
# ## Statistical Information

# %%
location_columns = ['Province_State', 'Country_Region', 'Last_Update', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Incidence_Rate', 'Case-Fatality_Ratio']
for attribute in location_columns:    
    print(f"statistics for {attribute} column")
    print(df_loc[attribute].describe())
    print("-------------------------")
# Out:
# statistics for Province_State column
# count      3786
# unique      562
# top       Texas
# freq        255
# Name: Province_State, dtype: object
# -------------------------
# statistics for Country_Region column
# count     3954
# unique     188
# top         US
# freq      3270
# Name: Country_Region, dtype: object
# -------------------------
# statistics for Last_Update column
# count                    3954
# unique                      3
# top       2020-09-20 04:22:56
# freq                     3951
# Name: Last_Update, dtype: object
# -------------------------
# statistics for Confirmed column
# count    3.954000e+03
# mean     7.760496e+03
# std      4.184036e+04
# min      0.000000e+00
# 25%      1.370000e+02
# 50%      4.985000e+02
# 75%      2.129000e+03
# max      1.167496e+06
# Name: Confirmed, dtype: float64
# -------------------------
# statistics for Deaths column
# count     3954.000000
# mean       241.740769
# std       1476.661533
# min          0.000000
# 25%          1.000000
# 50%          9.000000
# 75%         48.000000
# max      37076.000000
# Name: Deaths, dtype: float64
# -------------------------
# statistics for Recovered column
# count    3.954000e+03
# mean     5.291398e+03
# std      5.315287e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.577446e+06
# Name: Recovered, dtype: float64
# -------------------------
# statistics for Active column
# count    3.952000e+03
# mean     2.228632e+03
# std      4.440693e+04
# min     -2.577446e+06
# 25%      1.140000e+02
# 50%      4.210000e+02
# 75%      1.453000e+03
# max      3.379130e+05
# Name: Active, dtype: float64
# -------------------------
# statistics for Incidence_Rate column
# count     3874.000000
# mean      1538.572813
# std       1368.457332
# min          0.000000
# 25%        618.904146
# 50%       1204.351179
# 75%       2097.993633
# max      14871.183644
# Name: Incidence_Rate, dtype: float64
# -------------------------
# statistics for Case-Fatality_Ratio column
# count    3906.000000
# mean        2.355818
# std         3.538503
# min         0.000000
# 25%         0.637729
# 50%         1.633422
# 75%         3.006621
# max       108.812950
# Name: Case-Fatality_Ratio, dtype: float64
# -------------------------

# %% [markdown]
# ## Visualizations

# %%
attribute_hist_fig_sizes = [(50,4),(50,4),(1,4),(5,4),(5,4),(5,4),(5,4),(5,4),(5,4)]
for i, attribute in enumerate(location_columns):
    plt.figure()
    plt.title(attribute)
    df_loc[attribute].hist(figsize=attribute_hist_fig_sizes[i], xrot=90)

# %%
df_loc_agg = df_loc.groupby('Country_Region',as_index=False).agg(\
        {'Confirmed': 'sum', 'Deaths': 'sum', 'Recovered': 'sum', 'Active': 'sum', \
         'Incidence_Rate': 'mean', 'Case-Fatality_Ratio': 'mean'})
plt.figure(figsize=(50,4))
plt.title("Number of cases per countries for location.csv")
plt.xlabel("Country")
plt.ylabel("Count (in millions)")
plt.xticks(rotation=90)
df_loc_agg = df_loc_agg.sort_values(by='Confirmed', ascending=False) 
plt.plot(df_loc_agg['Country_Region'], df_loc_agg['Confirmed'])
plt.plot(df_loc_agg['Country_Region'], df_loc_agg['Deaths'])
plt.plot(df_loc_agg['Country_Region'], df_loc_agg['Recovered'])
plt.plot(df_loc_agg['Country_Region'], df_loc_agg['Active'])
plt.legend(['Confirmed', 'Deaths', 'Recovered', 'Active'], loc='upper right')
plt.savefig("../plots/location_conf-death-rec-active_by_country.png", facecolor='white', bbox_inches = "tight")

# top 20 countries
plt.figure(figsize=(15,4))
plt.title("Number of cases for top 20 countries for location.csv")
plt.xlabel("Country")
plt.ylabel("Count (in millions)")
plt.xticks(rotation=90)
df_loc_agg_top = df_loc_agg.head(20)
plt.plot(df_loc_agg_top['Country_Region'], df_loc_agg_top['Confirmed'])
plt.plot(df_loc_agg_top['Country_Region'], df_loc_agg_top['Deaths'])
plt.plot(df_loc_agg_top['Country_Region'], df_loc_agg_top['Recovered'])
plt.plot(df_loc_agg_top['Country_Region'], df_loc_agg_top['Active'])
plt.legend(['Confirmed', 'Deaths', 'Recovered', 'Active'], loc='upper right')
plt.savefig("../plots/location_conf-death-rec-active_by_top20_country.png", facecolor='white', bbox_inches = "tight")

# Incidence Rate 
plt.figure(figsize=(50,4))
plt.title("Incidence rate for countries in location.csv")
plt.xlabel("Country")
plt.ylabel("Incidence Rate (per 100,000)")
plt.xticks(rotation=90)
plt.plot(df_loc_agg['Country_Region'], df_loc_agg['Incidence_Rate'])
plt.savefig("../plots/location_incidence_rate_by_country.png", facecolor='white', bbox_inches = "tight")


# Case Fatality Ratio 
plt.figure(figsize=(50,4))
plt.title("Case fatality ratio for countries in location.csv")
plt.xlabel("Country")
plt.ylabel("Case fatality ratio")
plt.xticks(rotation=90)
plt.plot(df_loc_agg['Country_Region'], df_loc_agg['Case-Fatality_Ratio'])
plt.savefig("../plots/location_fatality_ratio_by_country.png", facecolor='white', bbox_inches = "tight")

# %%
# modified from https://stackoverflow.com/questions/53233228/plot-latitude-longitude-from-csv-in-python-3-6
geometry = [Point(xy) for xy in zip(df_loc['Long_'], df_loc['Lat'])]
gdf = GeoDataFrame(df_loc, geometry=geometry) 

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=1);
plt.title('Heatmap of Location Data')
plt.savefig("../plots/location_lat_long_mapped.png", facecolor='white', bbox_inches = "tight")

# %% [markdown]
# ## Number of Missing Values

# %%
df_loc.isnull().sum()
# Out:
# Province_State         168
# Country_Region           0
# Last_Update              0
# Lat                     80
# Long_                   80
# Confirmed                0
# Deaths                   0
# Recovered                0
# Active                   2
# Combined_Key             0
# Incidence_Rate          80
# Case-Fatality_Ratio     48
# geometry                 0
# dtype: int64
